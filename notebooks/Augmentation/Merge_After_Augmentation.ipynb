# %%
import pandas as pd

# %%
Aug_with_Noise = pd.read_csv("Added_Noise_augmented_data.csv")
Aug_with_CTGAN = pd.read_csv("augmented_merge_CTGAN.csv")

# %%
df_augumented_With_Noise_and_CTGAN = pd.concat([Aug_with_Noise, Aug_with_CTGAN], ignore_index=True)
df_augumented_With_Noise_and_CTGAN = df_augumented_With_Noise_and_CTGAN.drop_duplicates()

# %%
df_augumented_With_Noise_and_CTGAN.describe()
# Out:
#             Gender          Age  Sleep Duration  Quality of Sleep  \
# count  2981.000000  2981.000000     2981.000000       2981.000000
# mean      0.456223    38.945991        7.251448          6.235997
# std       0.498163    12.813771        1.826653          1.311359
# min       0.000000     5.000000        2.000000          0.782057
# 25%       0.000000    30.000000        6.000000          5.741391
# 50%       0.000000    38.000000        7.000000          6.307403
# 75%       1.000000    47.000000        8.253346          7.000000
# max       1.000000    90.000000       12.000000         10.000000
#
#        Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# count              2981.000000   2981.000000   2981.000000     2981.000000
# mean                 27.463603      5.575442      1.879571        1.568242
# std                  36.276952      2.420983      0.950409        0.192761
# ...

# %%
df_augumented_With_Noise_and_CTGAN.to_csv("augmented_merge_Noise_and_CTGAN.csv", index=False)
